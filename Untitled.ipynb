# %%
import pandas as pd

# %%
# !pip install pyshp
# !pip install pyproj

# %%
na_dthrts = pd.read_csv('death rates (2).txt', delimiter="\t")

# %%
na_dthrts[0:56]
# Out:
#    Notes                      County  County Code  \
# 0    NaN          Alameda County, CA       6001.0
# 1    NaN           Alpine County, CA       6003.0
# 2    NaN           Amador County, CA       6005.0
# 3    NaN            Butte County, CA       6007.0
# 4    NaN        Calaveras County, CA       6009.0
# 5    NaN           Colusa County, CA       6011.0
# 6    NaN     Contra Costa County, CA       6013.0
# 7    NaN        Del Norte County, CA       6015.0
# 8    NaN        El Dorado County, CA       6017.0
# 9    NaN           Fresno County, CA       6019.0
# 10   NaN            Glenn County, CA       6021.0
# 11   NaN         Humboldt County, CA       6023.0
# 12   NaN         Imperial County, CA       6025.0
# 13   NaN             Inyo County, CA       6027.0
# 14   NaN             Kern County, CA       6029.0
# 15   NaN            Kings County, CA       6031.0
# 16   NaN             Lake County, CA       6033.0
# 17   NaN           Lassen County, CA       6035.0
# ...

# %%
pyproj.transform(codes)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15352\3628552710.py in <module>
# ----> 1 pyproj.transform(codes)
#
# TypeError: transform() missing 3 required positional arguments: 'p2', 'x', and 'y'
